# %% [markdown]
# <a href="https://www.kaggle.com/code/eugenetanake/basic-web-scraping-s-pt-3-data-cleaning?scriptVersionId=97380488" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# importing the libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/basic-web-scraping-with-python-pt-2/webScrap2.csv
# /kaggle/input/basic-web-scraping-with-python-pt-2/__results__.html
# /kaggle/input/basic-web-scraping-with-python-pt-2/__resultx__.html
# /kaggle/input/basic-web-scraping-with-python-pt-2/__notebook__.ipynb
# /kaggle/input/basic-web-scraping-with-python-pt-2/__output__.json
# /kaggle/input/basic-web-scraping-with-python-pt-2/custom.css

# %%
df = pd.read_csv('/kaggle/input/basic-web-scraping-with-python-pt-2/webScrap2.csv')
df
# Out:
#                                           course name  \
# 0                  Microsoft Teams Essential Training
# 1                                  Outlook Quick Tips
# 2                          Introduction to RedisGraph
# 3               Azure Dapr for .NET Developers Part 1
# 4                Blockchain Programming in JavaScript
# 5             Learning Azure Kubernetes Service (AKS)
# 6                         Mapping to Learn with Figma
# 7                                       Git Workflows
# 8                        CRISC Cert Prep Audio Review
# 9                            Designing for Developers
# 10                                Git Code Challenges
# 11                  Linux: Desktops and Remote Access
# 12  Microsoft Security, Compliance, and Identity F...
# 13  Working with Staffing Agencies, Recruiters, He...
# 14        Foundations of Decentralized Finance (DeFi)
# 15                        JavaScript on the Go: Async
# 16            Learning Elementor for WordPress Design
# 17        Career Wellness Nano Tips with Shadé Zahrai
# 18         Job Interview Nano Tips with Madeline Mann
# 19                  Be the Manager People Won't Leave
# 20                         Revit: AR and VR Workflows
# 21  Expert Tips for Answering Common Interview Que...
# 22           Excel: VLOOKUP and XLOOKUP for Beginners
# 23  Excel Essential Training (Office 365/Microsoft...
# 24                     Dan Ariely on Making Decisions
# 25                     Animating in Historical Styles
# 26                     SOLIDWORKS: Modeling a Bicycle
# 27                   Excel: Lookup Functions in Depth
# 28                           Learning LinkedIn (2021)
# 29                     Project Management Foundations
# 30          The Six Morning Habits of High Performers
# 31                Outlook: Efficient Email Management
# 32             Excel: Advanced Formulas and Functions
# 33          Nano Tips for Using Excel with Miss Excel
# 34          Job Search Nano Tips with Jonathan Javier
# 35                             SQL Essential Training
# 36                          Body Language for Leaders
# 37                        Power BI Essential Training
# 38  Nano Tips for Communicating with Confidence wi...
# 39               How to Stop Wasting Time in Meetings
# 40                    Raspberry Pi Essential Training
# 41                      Communicating with Confidence
# 42                        Interpersonal Communication
# 43             Developing Your Emotional Intelligence
# 44                          Communication Foundations
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 0   https://www.linkedin.com/learning/microsoft-te...   2h 53m
# 1   https://www.linkedin.com/learning/outlook-quic...      27m
# 2   https://www.linkedin.com/learning/introduction...   1h 13m
# 3   https://www.linkedin.com/learning/azure-dapr-f...   1h 47m
# 4   https://www.linkedin.com/learning/blockchain-p...   1h 55m
# 5   https://www.linkedin.com/learning/learning-azu...   1h 18m
# 6   https://www.linkedin.com/learning/mapping-to-l...      31m
# 7   https://www.linkedin.com/learning/git-workflow...    1h 4m
# 8   https://www.linkedin.com/learning/crisc-cert-p...      51m
# 9   https://www.linkedin.com/learning/designing-fo...      10m
# 10  https://www.linkedin.com/learning/git-code-cha...      51m
# 11  https://www.linkedin.com/learning/linux-deskto...   2h 22m
# 12  https://www.linkedin.com/learning/microsoft-se...      39m
# 13  https://www.linkedin.com/learning/working-with...      37m
# 14  https://www.linkedin.com/learning/foundations-...      59m
# 15  https://www.linkedin.com/learning/javascript-o...      18m
# 16  https://www.linkedin.com/learning/learning-ele...   4h 12m
# 17  https://www.linkedin.com/learning/career-welln...       3m
# 18  https://www.linkedin.com/learning/job-intervie...       3m
# 19  https://www.linkedin.com/learning/be-the-manag...      28m
# 20  https://www.linkedin.com/learning/revit-ar-and...       2h
# 21  https://www.linkedin.com/learning/expert-tips-...   1h 14m
# 22  https://www.linkedin.com/learning/excel-vlooku...      19m
# 23  https://www.linkedin.com/learning/excel-essent...   2h 17m
# 24  https://www.linkedin.com/learning/dan-ariely-o...      57m
# 25  https://www.linkedin.com/learning/animating-in...   2h 39m
# 26  https://www.linkedin.com/learning/solidworks-m...    2h 3m
# 27  https://www.linkedin.com/learning/excel-lookup...    1h 8m
# 28  https://www.linkedin.com/learning/learning-lin...   1h 42m
# 29  https://www.linkedin.com/learning/project-mana...   3h 20m
# 30  https://www.linkedin.com/learning/the-six-morn...      23m
# 31  https://www.linkedin.com/learning/outlook-effi...   1h 55m
# 32  https://www.linkedin.com/learning/excel-advanc...   4h 47m
# 33  https://www.linkedin.com/learning/nano-tips-fo...       1m
# 34  https://www.linkedin.com/learning/job-search-n...       3m
# 35  https://www.linkedin.com/learning/sql-essentia...       3h
# 36  https://www.linkedin.com/learning/body-languag...      39m
# 37  https://www.linkedin.com/learning/power-bi-ess...   3h 24m
# 38  https://www.linkedin.com/learning/nano-tips-fo...      11m
# 39  https://www.linkedin.com/learning/how-to-stop-...      33m
# 40  https://www.linkedin.com/learning/raspberry-pi...   2h 19m
# 41  https://www.linkedin.com/learning/communicatin...   1h 16m
# 42  https://www.linkedin.com/learning/interpersona...      37m
# 43  https://www.linkedin.com/learning/developing-y...       1h
# 44  https://www.linkedin.com/learning/communicatio...   1h 17m
# 45  https://www.linkedin.com/learning/strategic-th...      36m
# 46  https://www.linkedin.com/learning/speaking-con...      22m
# 47  https://www.linkedin.com/learning/building-res...      34m
# 48  https://www.linkedin.com/learning/improving-yo...      56m
# 49  https://www.linkedin.com/learning/three-tips-f...      23m
#
#                                                    by       viewer count  \
# 0                                     By: Nick Brazzi                  0
# 1                                    By: Garrick Chow                  0
# 2                                 By: Ayaka Shinozaki                  0
# 3                             By: Rodrigo Díaz Concha                  0
# 4                                   By: Mohammad Azam                  0
# 5                                  By: Richard Hooper                  0
# 6                                  By: Drew Bridewell                  0
# 7                                  By: Kevin Bowersox                  0
# 8                                   By: Jerod Brennen                  0
# 9                                By: Joseph Labrecque                  0
# 10                                 By: Ray Villalobos                  0
# 11                               By: Grant McWilliams                  0
# 12                                    By: Pete Zerger                  0
# 13                                   By: Chris Taylor                  0
# 14                             By: Kedric Van de Carr                  0
# 15                                   By: Sasha Vodnik                  0
# 16                                      By: Emily Kay                  0
# 17                                   By: Shadé Zahrai    181,477 viewers
# 18                                  By: Madeline Mann    537,464 viewers
# 19                              By: Laurie Ruettimann  1,071,484 viewers
# 20                                    By: Logan Smith    243,740 viewers
# 21  By: Jenny Foss, LinkedIn Learning Instructors,...  1,641,135 viewers
# 22                                  By: Jess Stratton    785,513 viewers
# 23                                  By: Dennis Taylor  1,484,225 viewers
# 24                                     By: Dan Ariely    400,407 viewers
# 25                               By: Dermot O' Connor    339,773 viewers
# 26                                  By: Johno Ellison    102,501 viewers
# 27                                  By: Dennis Taylor  1,169,235 viewers
# 28                               By: Oliver Schinkten    374,949 viewers
# 29                                 By: Bonnie Biafore    873,595 viewers
# 30  By: Pete Mockaitis | How to Be Awesome at Your...  3,745,968 viewers
# 31                               By: Gini von Courter    677,953 viewers
# 32                                  By: Dennis Taylor  1,724,555 viewers
# 33                                     By: Kat Norton    196,188 viewers
# 34                                By: Jonathan Javier     48,912 viewers
# 35                                   By: Bill Weinman    584,294 viewers
# 36                             By: Carol Kinsey Goman    783,612 viewers
# 37                               By: Gini von Courter    493,818 viewers
# 38                                 By: Selena Rezvani     41,856 viewers
# 39                 By: Samantha Bennett and Madecraft    361,804 viewers
# 40                              By: Mark Niemann-Ross     83,504 viewers
# 41                                    By: Jeff Ansell  1,193,241 viewers
# 42                                    By: Dorie Clark    708,331 viewers
# 43                            By: Gemma Leigh Roberts  1,104,541 viewers
# 44       By: Brenda Bailey-Hughes and Tatiana Kolovou    668,565 viewers
# 45                                    By: Dorie Clark  1,405,614 viewers
# 46  By: Pete Mockaitis | How to Be Awesome at Your...    467,547 viewers
# 47                                By: Tatiana Kolovou    967,096 viewers
# 48                                  By: Dave Crenshaw    273,272 viewers
# 49  By: American Negotiation Institute and Kwame C...     34,063 viewers
#
#              release date                   likes  \
# 0    Released Jun 1, 2022        Liked by 2 users
# 1    Released Jun 1, 2022         Liked by 1 user
# 2    Released Jun 1, 2022         Liked by 1 user
# 3    Released Jun 1, 2022                     NaN
# 4    Released Jun 1, 2022                     NaN
# 5    Released Jun 2, 2022        Liked by 4 users
# 6    Released Jun 2, 2022                     NaN
# 7    Released Jun 2, 2022                     NaN
# 8   Released May 31, 2022                     NaN
# 9   Released May 31, 2022         Liked by 1 user
# 10  Released May 31, 2022                     NaN
# 11  Released May 31, 2022                     NaN
# 12  Released May 31, 2022        Liked by 2 users
# 13  Released May 31, 2022         Liked by 1 user
# 14  Released May 31, 2022       Liked by 10 users
# 15  Released May 31, 2022                     NaN
# 16   Released Jun 1, 2022        Liked by 2 users
# 17  Released Dec 15, 2021   Liked by 27,606 users
# 18  Released Dec 15, 2021   Liked by 12,301 users
# 19  Released Sep 17, 2021   Liked by 83,945 users
# 20  Released Nov 16, 2018   Liked by 16,260 users
# 21  Released Mar 11, 2019   Liked by 10,675 users
# 22   Released Aug 2, 2021   Liked by 80,803 users
# 23  Released Sep 24, 2018   Liked by 72,033 users
# 24  Released Jan 18, 2022   Liked by 10,516 users
# 25  Released Jun 17, 2021    Liked by 5,281 users
# 26   Released May 3, 2021   Liked by 14,166 users
# 27  Released Sep 11, 2020  Liked by 129,145 users
# 28  Released Feb 16, 2021   Liked by 49,777 users
# 29  Released Jun 28, 2019   Liked by 50,945 users
# 30  Released Jan 17, 2020  Liked by 165,364 users
# 31   Released Oct 4, 2019   Liked by 23,711 users
# 32   Released Apr 1, 2019   Liked by 79,640 users
# 33  Released Dec 15, 2021    Liked by 8,562 users
# 34  Released Dec 15, 2021    Liked by 1,777 users
# 35   Released Dec 3, 2019   Liked by 53,584 users
# 36  Released Aug 26, 2019   Liked by 23,406 users
# 37  Released Feb 21, 2020   Liked by 26,414 users
# 38  Released Mar 15, 2022    Liked by 2,037 users
# 39  Released Jun 21, 2021   Liked by 21,409 users
# 40  Released Jan 11, 2022    Liked by 8,605 users
# 41   Released Jun 3, 2015   Liked by 52,424 users
# 42  Released Jun 13, 2017   Liked by 24,206 users
# 43  Released May 23, 2017   Liked by 54,510 users
# 44  Released Jun 19, 2018   Liked by 24,949 users
# 45  Released Nov 13, 2017   Liked by 81,085 users
# 46  Released Nov 23, 2020   Liked by 30,515 users
# 47  Released Oct 15, 2014   Liked by 41,164 users
# 48  Released Jan 25, 2017    Liked by 8,127 users
# 49  Released May 21, 2021    Liked by 1,649 users
#
#                              skill level  rating rating max
# 0   Skill level: Beginner + Intermediate     NaN        NaN
# 1                   Skill level: General     NaN        NaN
# 2                  Skill level: Beginner     NaN        NaN
# 3              Skill level: Intermediate     NaN        NaN
# 4              Skill level: Intermediate     NaN        NaN
# 5              Skill level: Intermediate     NaN        NaN
# 6              Skill level: Intermediate     NaN        NaN
# 7              Skill level: Intermediate     NaN        NaN
# 8              Skill level: Intermediate     NaN        NaN
# 9              Skill level: Intermediate     NaN        NaN
# 10             Skill level: Intermediate     NaN        NaN
# 11             Skill level: Intermediate     NaN        NaN
# 12                 Skill level: Beginner     NaN        NaN
# 13                  Skill level: General     NaN        NaN
# 14                  Skill level: General     NaN        NaN
# 15             Skill level: Intermediate     NaN        NaN
# 16             Skill level: Intermediate     NaN        NaN
# 17                 Skill level: Beginner     4.7   out of 5
# 18                 Skill level: Beginner     4.5   out of 5
# 19  Skill level: Beginner + Intermediate     4.7   out of 5
# 20             Skill level: Intermediate     4.8   out of 5
# 21                 Skill level: Beginner     4.8   out of 5
# 22                 Skill level: Beginner     4.7   out of 5
# 23  Skill level: Beginner + Intermediate     4.8   out of 5
# 24                  Skill level: General     4.7   out of 5
# 25                 Skill level: Beginner     4.8   out of 5
# 26                 Skill level: Beginner     4.7   out of 5
# 27             Skill level: Intermediate     4.8   out of 5
# 28                 Skill level: Beginner     4.8   out of 5
# 29  Skill level: Beginner + Intermediate     4.7   out of 5
# 30                 Skill level: Beginner     4.5   out of 5
# 31             Skill level: Intermediate     4.7   out of 5
# 32                 Skill level: Advanced     4.8   out of 5
# 33                 Skill level: Beginner     2.8   out of 5
# 34                 Skill level: Beginner     4.1   out of 5
# 35                 Skill level: Beginner     4.7   out of 5
# 36                  Skill level: General     4.7   out of 5
# 37  Skill level: Beginner + Intermediate     4.7   out of 5
# 38                 Skill level: Beginner     4.7   out of 5
# 39                 Skill level: Beginner     4.7   out of 5
# 40                 Skill level: Beginner     4.7   out of 5
# 41                  Skill level: General     4.7   out of 5
# 42                 Skill level: Beginner     4.6   out of 5
# 43                 Skill level: Beginner     4.7   out of 5
# 44                 Skill level: Beginner     4.7   out of 5
# 45                 Skill level: Beginner     4.6   out of 5
# 46                 Skill level: Beginner     4.6   out of 5
# 47                  Skill level: General     4.7   out of 5
# 48                  Skill level: General     4.4   out of 5
# 49                 Skill level: Beginner     4.6   out of 5

# %% [markdown]
# Now that we have some data to work on, lets turn the values into a format we can work with.
#
# Among the four new lists, Skill level is not a numerical type of data. Lucky for us it seems to be ordinal, so we can replace it with numbers. Let us see what are the skill levels

# %%
df['skill level'].unique()
# Out:
# array(['Skill level: Beginner + Intermediate', 'Skill level: General',
#        'Skill level: Beginner', 'Skill level: Intermediate',
#        'Skill level: Advanced'], dtype=object)

# %% [markdown]
# Courses with Skill Level: General does not seem to be technical, I would likely to go with the following replacements:
#
# General - 1
#
# Beginner - 2
#
# Beginner + Intermediate - 2.5
#
# Intermediate - 3
#
# Advanced - 4

# %%
for i in range(len(df['skill level'])):
    level = df['skill level'][i].split(": ")
    levelNo = 0.0
    if level[1] == 'General':
        levelNo = 1.0
    elif level[1] == 'Beginner':
        levelNo = 2.0
    elif level[1] == 'Beginner + Intermediate':
        levelNo = 2.5
    elif level[1] == 'Intermediate':
        levelNo = 3.0
    elif level[1] == 'Advanced':
        levelNo = 4.0
    df['skill level'][i] = levelNo
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df["skill level"] = df["skill level"].astype(float)

# %% [markdown]
# There are three columns that we can turn into numerical data, namely the "viewer count", "release date" and "likes" columns. Let us work on those.

# %%
df["viewer count"] = df["viewer count"].replace(" viewers", "", regex=True)

# %%
df["viewer count"] = df["viewer count"].replace(",", "", regex=True)

# %%
df["viewer count"] = df["viewer count"].astype(int)

# %%
df.dtypes
# Out:
# course name      object
# url              object
# duration         object
# by               object
# viewer count      int64
# release date     object
# likes            object
# skill level     float64
# rating          float64
# rating max       object
# dtype: object

# %%
df.tail()
# Out:
#                                           course name  \
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 45  https://www.linkedin.com/learning/strategic-th...      36m
# 46  https://www.linkedin.com/learning/speaking-con...      22m
# 47  https://www.linkedin.com/learning/building-res...      34m
# 48  https://www.linkedin.com/learning/improving-yo...      56m
# 49  https://www.linkedin.com/learning/three-tips-f...      23m
#
#                                                    by  viewer count  \
# 45                                    By: Dorie Clark       1405614
# 46  By: Pete Mockaitis | How to Be Awesome at Your...        467547
# 47                                By: Tatiana Kolovou        967096
# 48                                  By: Dave Crenshaw        273272
# 49  By: American Negotiation Institute and Kwame C...         34063
#
#              release date                  likes  skill level  rating  \
# 45  Released Nov 13, 2017  Liked by 81,085 users          2.0     4.6
# 46  Released Nov 23, 2020  Liked by 30,515 users          2.0     4.6
# 47  Released Oct 15, 2014  Liked by 41,164 users          1.0     4.7
# 48  Released Jan 25, 2017   Liked by 8,127 users          1.0     4.4
# 49  Released May 21, 2021   Liked by 1,649 users          2.0     4.6
#
#    rating max
# 45   out of 5
# 46   out of 5
# 47   out of 5
# 48   out of 5
# 49   out of 5

# %%
df["likes"] = df["likes"].replace("Liked by", "", regex=True)
df["likes"] = df["likes"].replace(" users", "", regex=True)
df["likes"] = df["likes"].replace(",", "", regex=True)

# %%
df['likes'] = df["likes"].replace(" user", "", regex=True)

# %%
df['likes'] = df['likes'].fillna(0)

# %%
df['likes'] = df['likes'].astype(int)

# %%
df.tail()
# Out:
#                                           course name  \
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 45  https://www.linkedin.com/learning/strategic-th...      36m
# 46  https://www.linkedin.com/learning/speaking-con...      22m
# 47  https://www.linkedin.com/learning/building-res...      34m
# 48  https://www.linkedin.com/learning/improving-yo...      56m
# 49  https://www.linkedin.com/learning/three-tips-f...      23m
#
#                                                    by  viewer count  \
# 45                                    By: Dorie Clark       1405614
# 46  By: Pete Mockaitis | How to Be Awesome at Your...        467547
# 47                                By: Tatiana Kolovou        967096
# 48                                  By: Dave Crenshaw        273272
# 49  By: American Negotiation Institute and Kwame C...         34063
#
#              release date  likes  skill level  rating rating max
# 45  Released Nov 13, 2017  81085          2.0     4.6   out of 5
# 46  Released Nov 23, 2020  30515          2.0     4.6   out of 5
# 47  Released Oct 15, 2014  41164          1.0     4.7   out of 5
# 48  Released Jan 25, 2017   8127          1.0     4.4   out of 5
# 49  Released May 21, 2021   1649          2.0     4.6   out of 5

# %%
for i in range(len(df['duration'])):
    strings = df['duration'][i].split()
    minutes = 0
    for j in strings:
        if 'h' in j:
            minutes += int(j[:-1])*60
        if 'm' in j:
            minutes += int(j[:-1])
    df['duration'][i] = minutes
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":

# %%
df.tail()
# Out:
#                                           course name  \
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 45  https://www.linkedin.com/learning/strategic-th...       36
# 46  https://www.linkedin.com/learning/speaking-con...       22
# 47  https://www.linkedin.com/learning/building-res...       34
# 48  https://www.linkedin.com/learning/improving-yo...       56
# 49  https://www.linkedin.com/learning/three-tips-f...       23
#
#                                                    by  viewer count  \
# 45                                    By: Dorie Clark       1405614
# 46  By: Pete Mockaitis | How to Be Awesome at Your...        467547
# 47                                By: Tatiana Kolovou        967096
# 48                                  By: Dave Crenshaw        273272
# 49  By: American Negotiation Institute and Kwame C...         34063
#
#              release date  likes  skill level  rating rating max
# 45  Released Nov 13, 2017  81085          2.0     4.6   out of 5
# 46  Released Nov 23, 2020  30515          2.0     4.6   out of 5
# 47  Released Oct 15, 2014  41164          1.0     4.7   out of 5
# 48  Released Jan 25, 2017   8127          1.0     4.4   out of 5
# 49  Released May 21, 2021   1649          2.0     4.6   out of 5

# %%
df["release date"] = df["release date"].replace("Released ", "", regex=True)

# %%
df['release date'][0]
# Out:
# 'Jun 1, 2022'

# %%
df['release date'] = pd.to_datetime(
                          df['release date'],
                          format='%b %d, %Y'
)

# %%
df['release date'][0]
# Out:
# Timestamp('2022-06-01 00:00:00')

# %% [markdown]
# From this release date column, I would want to consider the amount of time that has passed since it's release date.

# %%
today = datetime.datetime(2022,6,2)
today - df['release date'][0]
# Out:
# Timedelta('1 days 00:00:00')

# %%
days = today-df['release date'][0]
releaseDays = days.days
releaseDays
# Out:
# 1

# %%
for i in range(len(df['release date'])):
    days = today - df['release date'][i]
    df['release date'][i] = days.days
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df
# Out:
#                                           course name  \
# 0                  Microsoft Teams Essential Training
# 1                                  Outlook Quick Tips
# 2                          Introduction to RedisGraph
# 3               Azure Dapr for .NET Developers Part 1
# 4                Blockchain Programming in JavaScript
# 5             Learning Azure Kubernetes Service (AKS)
# 6                         Mapping to Learn with Figma
# 7                                       Git Workflows
# 8                        CRISC Cert Prep Audio Review
# 9                            Designing for Developers
# 10                                Git Code Challenges
# 11                  Linux: Desktops and Remote Access
# 12  Microsoft Security, Compliance, and Identity F...
# 13  Working with Staffing Agencies, Recruiters, He...
# 14        Foundations of Decentralized Finance (DeFi)
# 15                        JavaScript on the Go: Async
# 16            Learning Elementor for WordPress Design
# 17        Career Wellness Nano Tips with Shadé Zahrai
# 18         Job Interview Nano Tips with Madeline Mann
# 19                  Be the Manager People Won't Leave
# 20                         Revit: AR and VR Workflows
# 21  Expert Tips for Answering Common Interview Que...
# 22           Excel: VLOOKUP and XLOOKUP for Beginners
# 23  Excel Essential Training (Office 365/Microsoft...
# 24                     Dan Ariely on Making Decisions
# 25                     Animating in Historical Styles
# 26                     SOLIDWORKS: Modeling a Bicycle
# 27                   Excel: Lookup Functions in Depth
# 28                           Learning LinkedIn (2021)
# 29                     Project Management Foundations
# 30          The Six Morning Habits of High Performers
# 31                Outlook: Efficient Email Management
# 32             Excel: Advanced Formulas and Functions
# 33          Nano Tips for Using Excel with Miss Excel
# 34          Job Search Nano Tips with Jonathan Javier
# 35                             SQL Essential Training
# 36                          Body Language for Leaders
# 37                        Power BI Essential Training
# 38  Nano Tips for Communicating with Confidence wi...
# 39               How to Stop Wasting Time in Meetings
# 40                    Raspberry Pi Essential Training
# 41                      Communicating with Confidence
# 42                        Interpersonal Communication
# 43             Developing Your Emotional Intelligence
# 44                          Communication Foundations
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 0   https://www.linkedin.com/learning/microsoft-te...      173
# 1   https://www.linkedin.com/learning/outlook-quic...       27
# 2   https://www.linkedin.com/learning/introduction...       73
# 3   https://www.linkedin.com/learning/azure-dapr-f...      107
# 4   https://www.linkedin.com/learning/blockchain-p...      115
# 5   https://www.linkedin.com/learning/learning-azu...       78
# 6   https://www.linkedin.com/learning/mapping-to-l...       31
# 7   https://www.linkedin.com/learning/git-workflow...       64
# 8   https://www.linkedin.com/learning/crisc-cert-p...       51
# 9   https://www.linkedin.com/learning/designing-fo...       10
# 10  https://www.linkedin.com/learning/git-code-cha...       51
# 11  https://www.linkedin.com/learning/linux-deskto...      142
# 12  https://www.linkedin.com/learning/microsoft-se...       39
# 13  https://www.linkedin.com/learning/working-with...       37
# 14  https://www.linkedin.com/learning/foundations-...       59
# 15  https://www.linkedin.com/learning/javascript-o...       18
# 16  https://www.linkedin.com/learning/learning-ele...      252
# 17  https://www.linkedin.com/learning/career-welln...        3
# 18  https://www.linkedin.com/learning/job-intervie...        3
# 19  https://www.linkedin.com/learning/be-the-manag...       28
# 20  https://www.linkedin.com/learning/revit-ar-and...      120
# 21  https://www.linkedin.com/learning/expert-tips-...       74
# 22  https://www.linkedin.com/learning/excel-vlooku...       19
# 23  https://www.linkedin.com/learning/excel-essent...      137
# 24  https://www.linkedin.com/learning/dan-ariely-o...       57
# 25  https://www.linkedin.com/learning/animating-in...      159
# 26  https://www.linkedin.com/learning/solidworks-m...      123
# 27  https://www.linkedin.com/learning/excel-lookup...       68
# 28  https://www.linkedin.com/learning/learning-lin...      102
# 29  https://www.linkedin.com/learning/project-mana...      200
# 30  https://www.linkedin.com/learning/the-six-morn...       23
# 31  https://www.linkedin.com/learning/outlook-effi...      115
# 32  https://www.linkedin.com/learning/excel-advanc...      287
# 33  https://www.linkedin.com/learning/nano-tips-fo...        1
# 34  https://www.linkedin.com/learning/job-search-n...        3
# 35  https://www.linkedin.com/learning/sql-essentia...      180
# 36  https://www.linkedin.com/learning/body-languag...       39
# 37  https://www.linkedin.com/learning/power-bi-ess...      204
# 38  https://www.linkedin.com/learning/nano-tips-fo...       11
# 39  https://www.linkedin.com/learning/how-to-stop-...       33
# 40  https://www.linkedin.com/learning/raspberry-pi...      139
# 41  https://www.linkedin.com/learning/communicatin...       76
# 42  https://www.linkedin.com/learning/interpersona...       37
# 43  https://www.linkedin.com/learning/developing-y...       60
# 44  https://www.linkedin.com/learning/communicatio...       77
# 45  https://www.linkedin.com/learning/strategic-th...       36
# 46  https://www.linkedin.com/learning/speaking-con...       22
# 47  https://www.linkedin.com/learning/building-res...       34
# 48  https://www.linkedin.com/learning/improving-yo...       56
# 49  https://www.linkedin.com/learning/three-tips-f...       23
#
#                                                    by  viewer count  \
# 0                                     By: Nick Brazzi             0
# 1                                    By: Garrick Chow             0
# 2                                 By: Ayaka Shinozaki             0
# 3                             By: Rodrigo Díaz Concha             0
# 4                                   By: Mohammad Azam             0
# 5                                  By: Richard Hooper             0
# 6                                  By: Drew Bridewell             0
# 7                                  By: Kevin Bowersox             0
# 8                                   By: Jerod Brennen             0
# 9                                By: Joseph Labrecque             0
# 10                                 By: Ray Villalobos             0
# 11                               By: Grant McWilliams             0
# 12                                    By: Pete Zerger             0
# 13                                   By: Chris Taylor             0
# 14                             By: Kedric Van de Carr             0
# 15                                   By: Sasha Vodnik             0
# 16                                      By: Emily Kay             0
# 17                                   By: Shadé Zahrai        181477
# 18                                  By: Madeline Mann        537464
# 19                              By: Laurie Ruettimann       1071484
# 20                                    By: Logan Smith        243740
# 21  By: Jenny Foss, LinkedIn Learning Instructors,...       1641135
# 22                                  By: Jess Stratton        785513
# 23                                  By: Dennis Taylor       1484225
# 24                                     By: Dan Ariely        400407
# 25                               By: Dermot O' Connor        339773
# 26                                  By: Johno Ellison        102501
# 27                                  By: Dennis Taylor       1169235
# 28                               By: Oliver Schinkten        374949
# 29                                 By: Bonnie Biafore        873595
# 30  By: Pete Mockaitis | How to Be Awesome at Your...       3745968
# 31                               By: Gini von Courter        677953
# 32                                  By: Dennis Taylor       1724555
# 33                                     By: Kat Norton        196188
# 34                                By: Jonathan Javier         48912
# 35                                   By: Bill Weinman        584294
# 36                             By: Carol Kinsey Goman        783612
# 37                               By: Gini von Courter        493818
# 38                                 By: Selena Rezvani         41856
# 39                 By: Samantha Bennett and Madecraft        361804
# 40                              By: Mark Niemann-Ross         83504
# 41                                    By: Jeff Ansell       1193241
# 42                                    By: Dorie Clark        708331
# 43                            By: Gemma Leigh Roberts       1104541
# 44       By: Brenda Bailey-Hughes and Tatiana Kolovou        668565
# 45                                    By: Dorie Clark       1405614
# 46  By: Pete Mockaitis | How to Be Awesome at Your...        467547
# 47                                By: Tatiana Kolovou        967096
# 48                                  By: Dave Crenshaw        273272
# 49  By: American Negotiation Institute and Kwame C...         34063
#
#    release date   likes  skill level  rating rating max
# 0             1       2          2.5     NaN        NaN
# 1             1       1          1.0     NaN        NaN
# 2             1       1          2.0     NaN        NaN
# 3             1       0          3.0     NaN        NaN
# 4             1       0          3.0     NaN        NaN
# 5             0       4          3.0     NaN        NaN
# 6             0       0          3.0     NaN        NaN
# 7             0       0          3.0     NaN        NaN
# 8             2       0          3.0     NaN        NaN
# 9             2       1          3.0     NaN        NaN
# 10            2       0          3.0     NaN        NaN
# 11            2       0          3.0     NaN        NaN
# 12            2       2          2.0     NaN        NaN
# 13            2       1          1.0     NaN        NaN
# 14            2      10          1.0     NaN        NaN
# 15            2       0          3.0     NaN        NaN
# 16            1       2          3.0     NaN        NaN
# 17          169   27606          2.0     4.7   out of 5
# 18          169   12301          2.0     4.5   out of 5
# 19          258   83945          2.5     4.7   out of 5
# 20         1294   16260          3.0     4.8   out of 5
# 21         1179   10675          2.0     4.8   out of 5
# 22          304   80803          2.0     4.7   out of 5
# 23         1347   72033          2.5     4.8   out of 5
# 24          135   10516          1.0     4.7   out of 5
# 25          350    5281          2.0     4.8   out of 5
# 26          395   14166          2.0     4.7   out of 5
# 27          629  129145          3.0     4.8   out of 5
# 28          471   49777          2.0     4.8   out of 5
# 29         1070   50945          2.5     4.7   out of 5
# 30          867  165364          2.0     4.5   out of 5
# 31          972   23711          3.0     4.7   out of 5
# 32         1158   79640          4.0     4.8   out of 5
# 33          169    8562          2.0     2.8   out of 5
# 34          169    1777          2.0     4.1   out of 5
# 35          912   53584          2.0     4.7   out of 5
# 36         1011   23406          1.0     4.7   out of 5
# 37          832   26414          2.5     4.7   out of 5
# 38           79    2037          2.0     4.7   out of 5
# 39          346   21409          2.0     4.7   out of 5
# 40          142    8605          2.0     4.7   out of 5
# 41         2556   52424          1.0     4.7   out of 5
# 42         1815   24206          2.0     4.6   out of 5
# 43         1836   54510          2.0     4.7   out of 5
# 44         1444   24949          2.0     4.7   out of 5
# 45         1662   81085          2.0     4.6   out of 5
# 46          556   30515          2.0     4.6   out of 5
# 47         2787   41164          1.0     4.7   out of 5
# 48         1954    8127          1.0     4.4   out of 5
# 49          377    1649          2.0     4.6   out of 5

# %% [markdown]
# For simplicity's sake, I will not take into account who the course is by. One potential factor could be how many courses that person/group have conducted, how the other courses fared, which could lead to people looking at the other courses the instructor conducted, which would complicate things even further.
#
# I will also not take into account the course title. There are advanced techniques which I am not yet familiar with to calculate the weight of the words in the course title.
#
# As all rows have the same value for "rating max", we can safely exclude that variable as well.
#
# As data from the first 14 rows are brand new (released for <5 days) we shall exclude them for calculations.
#
# What is interesting is the ratings. Let us take a look.

# %%
df['rating'].value_counts()
# Out:
# 4.7    17
# 4.8     7
# 4.6     4
# 4.5     2
# 2.8     1
# 4.1     1
# 4.4     1
# Name: rating, dtype: int64

# %%
df['rating'].describe()
# Out:
# count    33.000000
# mean      4.612121
# std       0.353339
# min       2.800000
# 25%       4.600000
# 50%       4.700000
# 75%       4.700000
# max       4.800000
# Name: rating, dtype: float64

# %%
df.loc[df['rating'] == 2.8]
# Out:
#                                   course name  \
# 33  Nano Tips for Using Excel with Miss Excel
#
#                                                   url duration  \
# 33  https://www.linkedin.com/learning/nano-tips-fo...        1
#
#                 by  viewer count release date  likes  skill level  rating  \
# 33  By: Kat Norton        196188          169   8562          2.0     2.8
#
#    rating max
# 33   out of 5

# %%
df['url'][30]
# Out:
# 'https://www.linkedin.com/learning/the-six-morning-habits-of-high-performers?trk=learning-serp_learning-search-card_search-card'

# %% [markdown]
# In short, that "course" is something you would find on youtube. Imagine dancing and singing out your presentation in a meeting with your boss. I'm kicking it out of my data. Did not expect this to be included in LinkedIn

# %%
df = df.loc[df['rating'] > 3]
df
# Out:
#                                           course name  \
# 17        Career Wellness Nano Tips with Shadé Zahrai
# 18         Job Interview Nano Tips with Madeline Mann
# 19                  Be the Manager People Won't Leave
# 20                         Revit: AR and VR Workflows
# 21  Expert Tips for Answering Common Interview Que...
# 22           Excel: VLOOKUP and XLOOKUP for Beginners
# 23  Excel Essential Training (Office 365/Microsoft...
# 24                     Dan Ariely on Making Decisions
# 25                     Animating in Historical Styles
# 26                     SOLIDWORKS: Modeling a Bicycle
# 27                   Excel: Lookup Functions in Depth
# 28                           Learning LinkedIn (2021)
# 29                     Project Management Foundations
# 30          The Six Morning Habits of High Performers
# 31                Outlook: Efficient Email Management
# 32             Excel: Advanced Formulas and Functions
# 34          Job Search Nano Tips with Jonathan Javier
# 35                             SQL Essential Training
# 36                          Body Language for Leaders
# 37                        Power BI Essential Training
# 38  Nano Tips for Communicating with Confidence wi...
# 39               How to Stop Wasting Time in Meetings
# 40                    Raspberry Pi Essential Training
# 41                      Communicating with Confidence
# 42                        Interpersonal Communication
# 43             Developing Your Emotional Intelligence
# 44                          Communication Foundations
# 45                                 Strategic Thinking
# 46               Speaking Confidently and Effectively
# 47                                Building Resilience
# 48                               Improving Your Focus
# 49  Three Tips for Managing Egos and Difficult Emo...
#
#                                                   url duration  \
# 17  https://www.linkedin.com/learning/career-welln...        3
# 18  https://www.linkedin.com/learning/job-intervie...        3
# 19  https://www.linkedin.com/learning/be-the-manag...       28
# 20  https://www.linkedin.com/learning/revit-ar-and...      120
# 21  https://www.linkedin.com/learning/expert-tips-...       74
# 22  https://www.linkedin.com/learning/excel-vlooku...       19
# 23  https://www.linkedin.com/learning/excel-essent...      137
# 24  https://www.linkedin.com/learning/dan-ariely-o...       57
# 25  https://www.linkedin.com/learning/animating-in...      159
# 26  https://www.linkedin.com/learning/solidworks-m...      123
# 27  https://www.linkedin.com/learning/excel-lookup...       68
# 28  https://www.linkedin.com/learning/learning-lin...      102
# 29  https://www.linkedin.com/learning/project-mana...      200
# 30  https://www.linkedin.com/learning/the-six-morn...       23
# 31  https://www.linkedin.com/learning/outlook-effi...      115
# 32  https://www.linkedin.com/learning/excel-advanc...      287
# 34  https://www.linkedin.com/learning/job-search-n...        3
# 35  https://www.linkedin.com/learning/sql-essentia...      180
# 36  https://www.linkedin.com/learning/body-languag...       39
# 37  https://www.linkedin.com/learning/power-bi-ess...      204
# 38  https://www.linkedin.com/learning/nano-tips-fo...       11
# 39  https://www.linkedin.com/learning/how-to-stop-...       33
# 40  https://www.linkedin.com/learning/raspberry-pi...      139
# 41  https://www.linkedin.com/learning/communicatin...       76
# 42  https://www.linkedin.com/learning/interpersona...       37
# 43  https://www.linkedin.com/learning/developing-y...       60
# 44  https://www.linkedin.com/learning/communicatio...       77
# 45  https://www.linkedin.com/learning/strategic-th...       36
# 46  https://www.linkedin.com/learning/speaking-con...       22
# 47  https://www.linkedin.com/learning/building-res...       34
# 48  https://www.linkedin.com/learning/improving-yo...       56
# 49  https://www.linkedin.com/learning/three-tips-f...       23
#
#                                                    by  viewer count  \
# 17                                   By: Shadé Zahrai        181477
# 18                                  By: Madeline Mann        537464
# 19                              By: Laurie Ruettimann       1071484
# 20                                    By: Logan Smith        243740
# 21  By: Jenny Foss, LinkedIn Learning Instructors,...       1641135
# 22                                  By: Jess Stratton        785513
# 23                                  By: Dennis Taylor       1484225
# 24                                     By: Dan Ariely        400407
# 25                               By: Dermot O' Connor        339773
# 26                                  By: Johno Ellison        102501
# 27                                  By: Dennis Taylor       1169235
# 28                               By: Oliver Schinkten        374949
# 29                                 By: Bonnie Biafore        873595
# 30  By: Pete Mockaitis | How to Be Awesome at Your...       3745968
# 31                               By: Gini von Courter        677953
# 32                                  By: Dennis Taylor       1724555
# 34                                By: Jonathan Javier         48912
# 35                                   By: Bill Weinman        584294
# 36                             By: Carol Kinsey Goman        783612
# 37                               By: Gini von Courter        493818
# 38                                 By: Selena Rezvani         41856
# 39                 By: Samantha Bennett and Madecraft        361804
# 40                              By: Mark Niemann-Ross         83504
# 41                                    By: Jeff Ansell       1193241
# 42                                    By: Dorie Clark        708331
# 43                            By: Gemma Leigh Roberts       1104541
# 44       By: Brenda Bailey-Hughes and Tatiana Kolovou        668565
# 45                                    By: Dorie Clark       1405614
# 46  By: Pete Mockaitis | How to Be Awesome at Your...        467547
# 47                                By: Tatiana Kolovou        967096
# 48                                  By: Dave Crenshaw        273272
# 49  By: American Negotiation Institute and Kwame C...         34063
#
#    release date   likes  skill level  rating rating max
# 17          169   27606          2.0     4.7   out of 5
# 18          169   12301          2.0     4.5   out of 5
# 19          258   83945          2.5     4.7   out of 5
# 20         1294   16260          3.0     4.8   out of 5
# 21         1179   10675          2.0     4.8   out of 5
# 22          304   80803          2.0     4.7   out of 5
# 23         1347   72033          2.5     4.8   out of 5
# 24          135   10516          1.0     4.7   out of 5
# 25          350    5281          2.0     4.8   out of 5
# 26          395   14166          2.0     4.7   out of 5
# 27          629  129145          3.0     4.8   out of 5
# 28          471   49777          2.0     4.8   out of 5
# 29         1070   50945          2.5     4.7   out of 5
# 30          867  165364          2.0     4.5   out of 5
# 31          972   23711          3.0     4.7   out of 5
# 32         1158   79640          4.0     4.8   out of 5
# 34          169    1777          2.0     4.1   out of 5
# 35          912   53584          2.0     4.7   out of 5
# 36         1011   23406          1.0     4.7   out of 5
# 37          832   26414          2.5     4.7   out of 5
# 38           79    2037          2.0     4.7   out of 5
# 39          346   21409          2.0     4.7   out of 5
# 40          142    8605          2.0     4.7   out of 5
# 41         2556   52424          1.0     4.7   out of 5
# 42         1815   24206          2.0     4.6   out of 5
# 43         1836   54510          2.0     4.7   out of 5
# 44         1444   24949          2.0     4.7   out of 5
# 45         1662   81085          2.0     4.6   out of 5
# 46          556   30515          2.0     4.6   out of 5
# 47         2787   41164          1.0     4.7   out of 5
# 48         1954    8127          1.0     4.4   out of 5
# 49          377    1649          2.0     4.6   out of 5

# %%
os.chdir(r'/kaggle/working')

df.to_csv(r'webScrap3.csv', index = False)
